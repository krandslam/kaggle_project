# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#데이터-불러오기" data-toc-modified-id="데이터-불러오기-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>데이터 불러오기</a></span></li><li><span><a href="#데이터-전처리" data-toc-modified-id="데이터-전처리-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>데이터 전처리</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#결측치-파악하기" data-toc-modified-id="결측치-파악하기-2.0.1"><span class="toc-item-num">2.0.1&nbsp;&nbsp;</span>결측치 파악하기</a></span></li><li><span><a href="#결측치-채우기-2번-방법-:-그대로-사용하기-(Others로-분류)" data-toc-modified-id="결측치-채우기-2번-방법-:-그대로-사용하기-(Others로-분류)-2.0.2"><span class="toc-item-num">2.0.2&nbsp;&nbsp;</span>결측치 채우기 2번 방법 : 그대로 사용하기 (Others로 분류)</a></span></li><li><span><a href="#데이터-시각화" data-toc-modified-id="데이터-시각화-2.0.3"><span class="toc-item-num">2.0.3&nbsp;&nbsp;</span>데이터 시각화</a></span></li><li><span><a href="#데이터-컬럼-병합-및-삭제" data-toc-modified-id="데이터-컬럼-병합-및-삭제-2.0.4"><span class="toc-item-num">2.0.4&nbsp;&nbsp;</span>데이터 컬럼 병합 및 삭제</a></span></li></ul></li></ul></li><li><span><a href="#모델-예측" data-toc-modified-id="모델-예측-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>모델 예측</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#문제,-정답-데이터로-분리" data-toc-modified-id="문제,-정답-데이터로-분리-3.0.1"><span class="toc-item-num">3.0.1&nbsp;&nbsp;</span>문제, 정답 데이터로 분리</a></span></li><li><span><a href="#훈련,-테스트-데이터-원핫-인코딩-하기" data-toc-modified-id="훈련,-테스트-데이터-원핫-인코딩-하기-3.0.2"><span class="toc-item-num">3.0.2&nbsp;&nbsp;</span>훈련, 테스트 데이터 원핫 인코딩 하기</a></span></li><li><span><a href="#컬럼-개수-맞추기" data-toc-modified-id="컬럼-개수-맞추기-3.0.3"><span class="toc-item-num">3.0.3&nbsp;&nbsp;</span>컬럼 개수 맞추기</a></span></li><li><span><a href="#Scaler-생성하기" data-toc-modified-id="Scaler-생성하기-3.0.4"><span class="toc-item-num">3.0.4&nbsp;&nbsp;</span>Scaler 생성하기</a></span></li><li><span><a href="#모델-생성하기" data-toc-modified-id="모델-생성하기-3.0.5"><span class="toc-item-num">3.0.5&nbsp;&nbsp;</span>모델 생성하기</a></span></li><li><span><a href="#교차-검증하기" data-toc-modified-id="교차-검증하기-3.0.6"><span class="toc-item-num">3.0.6&nbsp;&nbsp;</span>교차 검증하기</a></span></li></ul></li></ul></li><li><span><a href="#Kaggle-제출용-파일-만들기" data-toc-modified-id="Kaggle-제출용-파일-만들기-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Kaggle 제출용 파일 만들기</a></span></li></ul></div>

# %% [markdown]
# # 데이터 불러오기

# %%
import numpy as np
import pandas as pd

# %%
train = pd.read_csv('train.csv', index_col = 'no')
test = pd.read_csv('test.csv', index_col = 'no')

train
# Out:
#        age          workclass  fnlwgt      education  education-num  \
# no
# 1       25            Private  219199           11th              7
# 2       39            Private   52978   Some-college             10
# 3       35            Private  196899      Bachelors             13
# 4       64            Private  135527      Assoc-voc             11
# 5       24            Private   60783   Some-college             10
# ...    ...                ...     ...            ...            ...
# 29301   20            Private  100605        HS-grad              9
# 29302   21            Private  372636        HS-grad              9
# 29303   18   Self-emp-not-inc  258474           10th              6
# 29304   33            Private  157446           11th              7
# 29305   65                  ?   94809        HS-grad              9
#
#             marital-status          occupation    relationship  \
# no
# 1                 Divorced   Machine-op-inspct   Not-in-family
# ...

# %%
test
# Out:
#        age          workclass  fnlwgt      education  education-num  \
# no
# 29306   18                  ?  245274   Some-college             10
# 29307   29            Private   83003        HS-grad              9
# 29308   45            Private   35136      Bachelors             13
# 29309   42   Self-emp-not-inc   64631      Bachelors             13
# 29310   41            Private  195821      Doctorate             16
# ...    ...                ...     ...            ...            ...
# 48838   45   Self-emp-not-inc  116789        HS-grad              9
# 48839   48            Private  185079        HS-grad              9
# 48840   63            Private  117473   Some-college             10
# 48841   18            Private  150817           11th              7
# 48842   31            Private  341632     Assoc-acdm             12
#
#             marital-status        occupation    relationship    race      sex  \
# no
# ...

# %%
print(train.shape)
print(test.shape)
# Out:
# (29305, 15)
# (19537, 14)

# %% [markdown]
# # 데이터 전처리

# %% [markdown]
# ### 결측치 파악하기

# %% [markdown]
# 범주형 데이터 결측치 파악

# %%
train['workclass'].value_counts()                 # workclass 결측치 있음, 4번째로 많은 범주에 해당
# Out:
#  Private             20410
#  Self-emp-not-inc     2305
#  Local-gov            1868
#  ?                    1663
#  State-gov            1201
#  Self-emp-inc          987
#  Federal-gov           854
#  Without-pay            12
#  Never-worked            5
# Name: workclass, dtype: int64

# %%
test['workclass'].value_counts()
# Out:
#  Private             13496
#  Self-emp-not-inc     1557
#  Local-gov            1268
#  ?                    1136
#  State-gov             780
#  Self-emp-inc          708
#  Federal-gov           578
#  Without-pay             9
#  Never-worked            5
# Name: workclass, dtype: int64

# %%
train['education'].value_counts()
# Out:
#  HS-grad         9435
#  Some-college    6558
#  Bachelors       4848
#  Masters         1587
#  Assoc-voc       1230
#  11th            1057
#  Assoc-acdm       980
#  10th             816
#  7th-8th          574
#  Prof-school      500
#  9th              430
#  12th             415
#  Doctorate        347
#  5th-6th          334
#  1st-4th          148
#  Preschool         46
# Name: education, dtype: int64

# %%
train['marital-status'].value_counts()
# Out:
#  Married-civ-spouse       13331
#  Never-married             9673
#  Divorced                  4030
#  Widowed                    942
#  Separated                  914
#  Married-spouse-absent      394
#  Married-AF-spouse           21
# Name: marital-status, dtype: int64

# %%
train['occupation'].value_counts()                  # occupation  결측치 있음, 중간정도로 많은 범주에 해당
# Out:
#  Prof-specialty       3724
#  Craft-repair         3632
#  Exec-managerial      3609
#  Adm-clerical         3440
#  Sales                3292
#  Other-service        2975
#  Machine-op-inspct    1811
#  ?                    1668
#  Transport-moving     1393
#  Handlers-cleaners    1249
#  Farming-fishing       888
#  Tech-support          865
#  Protective-serv       603
#  Priv-house-serv       146
#  Armed-Forces           10
# Name: occupation, dtype: int64

# %%
test['occupation'].value_counts()                  # occupation  결측치 있음, 중간정도로 많은 범주에 해당
# Out:
#  Craft-repair         2480
#  Exec-managerial      2477
#  Prof-specialty       2448
#  Sales                2212
#  Adm-clerical         2171
#  Other-service        1948
#  Machine-op-inspct    1211
#  ?                    1141
#  Transport-moving      962
#  Handlers-cleaners     823
#  Farming-fishing       602
#  Tech-support          581
#  Protective-serv       380
#  Priv-house-serv        96
#  Armed-Forces            5
# Name: occupation, dtype: int64

# %%
train['relationship'].value_counts()
# Out:
#  Husband           11769
#  Not-in-family      7637
#  Own-child          4554
#  Unmarried          3071
#  Wife               1370
#  Other-relative      904
# Name: relationship, dtype: int64

# %%
train['race'].value_counts()
# Out:
#  White                 25081
#  Black                  2776
#  Asian-Pac-Islander      919
#  Amer-Indian-Eskimo      290
#  Other                   239
# Name: race, dtype: int64

# %%
train['sex'].value_counts()
# Out:
#  Male      19621
#  Female     9684
# Name: sex, dtype: int64

# %%
train['native-country'].value_counts()             # native-country 결측치 있음, 3번째로 많은 범주에 해당
# Out:
#  United-States                 26301
#  Mexico                          579
#  ?                               495
#  Philippines                     178
#  Germany                         124
#  Puerto-Rico                     117
#  Canada                          111
#  El-Salvador                      96
#  Cuba                             94
#  India                            90
#  England                          75
#  South                            74
#  Jamaica                          68
#  China                            68
#  Dominican-Republic               61
#  Italy                            60
#  Japan                            54
#  Poland                           53
#  Columbia                         53
#  Haiti                            51
#  Guatemala                        51
#  Vietnam                          50
#  Portugal                         43
#  Taiwan                           39
#  Iran                             38
# ...

# %%
test['native-country'].value_counts()             # native-country 결측치 있음, 3번째로 많은 범주에 해당
# Out:
#  United-States                 17531
#  Mexico                          372
#  ?                               362
#  Philippines                     117
#  Germany                          82
#  Canada                           71
#  Puerto-Rico                      67
#  India                            61
#  El-Salvador                      59
#  China                            54
#  England                          52
#  Italy                            45
#  Cuba                             44
#  Dominican-Republic               42
#  South                            41
#  Japan                            38
#  Jamaica                          38
#  Guatemala                        37
#  Vietnam                          36
#  Poland                           34
#  Columbia                         32
#  Taiwan                           26
#  Greece                           24
#  Portugal                         24
#  Ecuador                          24
# ...

# %%
train['income'].value_counts()
# Out:
# 0    22260
# 1     7045
# Name: income, dtype: int64

# %% [markdown]
# 숫자형 데이터 결측치 파악

# %%
train
# Out:
#        age          workclass  fnlwgt      education  education-num  \
# no
# 1       25            Private  219199           11th              7
# 2       39            Private   52978   Some-college             10
# 3       35            Private  196899      Bachelors             13
# 4       64            Private  135527      Assoc-voc             11
# 5       24            Private   60783   Some-college             10
# ...    ...                ...     ...            ...            ...
# 29301   20            Private  100605        HS-grad              9
# 29302   21            Private  372636        HS-grad              9
# 29303   18   Self-emp-not-inc  258474           10th              6
# 29304   33            Private  157446           11th              7
# 29305   65                  ?   94809        HS-grad              9
#
#             marital-status          occupation    relationship  \
# no
# 1                 Divorced   Machine-op-inspct   Not-in-family
# ...

# %%
is_question = train['age'] == " ?"
train[is_question]                           # 모든 숫자형 컬럼 확인 결과 결측치 없음!!
# Out:
# C:\Users\163900\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)
# Empty DataFrame
# Columns: [age, workclass, fnlwgt, education, education-num, marital-status, occupation, relationship, race, sex, capital-gain, capital-loss, hours-per-week, native-country, income]
# Index: []

# %% [markdown]
# workclass : 1663,
# occupation : 1668,
# native-country : 495 결측치 존재

# %% [markdown]
# ### 결측치 채우기 2번 방법 : 그대로 사용하기 (Others로 분류)

# %% [markdown]
# workclass 결측치 채우기

# %%
train['workclass'] = train['workclass'].replace(" ?", "Others")

# %%
train['workclass'].value_counts()                     # train의 workclass 결측치: ?  -> Others로 변경 됐다!
# Out:
#  Private             20410
#  Self-emp-not-inc     2305
#  Local-gov            1868
# Others                1663
#  State-gov            1201
#  Self-emp-inc          987
#  Federal-gov           854
#  Without-pay            12
#  Never-worked            5
# Name: workclass, dtype: int64

# %%
test['workclass'] = test['workclass'].replace(" ?", "Others")

# %%
test['workclass'].value_counts()                     # test의 workclass 결측치: ?  -> Others로 변경 됐다!
# Out:
#  Private             13496
#  Self-emp-not-inc     1557
#  Local-gov            1268
# Others                1136
#  State-gov             780
#  Self-emp-inc          708
#  Federal-gov           578
#  Without-pay             9
#  Never-worked            5
# Name: workclass, dtype: int64

# %% [markdown]
# occupation 결측치 채우기

# %%
train['occupation'] = train['occupation'].replace(" ?", "Others")

# %%
train['occupation'].value_counts()                         # occupation 결측치: ?  -> Others로 변경 됐다!
# Out:
#  Prof-specialty       3724
#  Craft-repair         3632
#  Exec-managerial      3609
#  Adm-clerical         3440
#  Sales                3292
#  Other-service        2975
#  Machine-op-inspct    1811
# Others                1668
#  Transport-moving     1393
#  Handlers-cleaners    1249
#  Farming-fishing       888
#  Tech-support          865
#  Protective-serv       603
#  Priv-house-serv       146
#  Armed-Forces           10
# Name: occupation, dtype: int64

# %%
test['occupation'] = test['occupation'].replace(" ?", "Others")

# %%
test['occupation'].value_counts()                         # test의 occupation 결측치: ?  -> Others로 변경 됐다!
# Out:
#  Craft-repair         2480
#  Exec-managerial      2477
#  Prof-specialty       2448
#  Sales                2212
#  Adm-clerical         2171
#  Other-service        1948
#  Machine-op-inspct    1211
# Others                1141
#  Transport-moving      962
#  Handlers-cleaners     823
#  Farming-fishing       602
#  Tech-support          581
#  Protective-serv       380
#  Priv-house-serv        96
#  Armed-Forces            5
# Name: occupation, dtype: int64

# %% [markdown]
# native-country 결측치 채우기

# %%
train['native-country'] = train['native-country'].replace(" ?", "Others")

# %%
train['native-country'].value_counts()                           # native-country 결측치: ?  -> Others로 변경 됐다!
# Out:
#  United-States                 26301
#  Mexico                          579
# Others                           495
#  Philippines                     178
#  Germany                         124
#  Puerto-Rico                     117
#  Canada                          111
#  El-Salvador                      96
#  Cuba                             94
#  India                            90
#  England                          75
#  South                            74
#  China                            68
#  Jamaica                          68
#  Dominican-Republic               61
#  Italy                            60
#  Japan                            54
#  Columbia                         53
#  Poland                           53
#  Guatemala                        51
#  Haiti                            51
#  Vietnam                          50
#  Portugal                         43
#  Taiwan                           39
#  Iran                             38
# ...

# %%
test['native-country'] = test['native-country'].replace(" ?", "Others")

# %%
test['native-country'].value_counts()                           # test의 native-country 결측치: ?  -> Others로 변경 됐다!
# Out:
#  United-States                 17531
#  Mexico                          372
# Others                           362
#  Philippines                     117
#  Germany                          82
#  Canada                           71
#  Puerto-Rico                      67
#  India                            61
#  El-Salvador                      59
#  China                            54
#  England                          52
#  Italy                            45
#  Cuba                             44
#  Dominican-Republic               42
#  South                            41
#  Japan                            38
#  Jamaica                          38
#  Guatemala                        37
#  Vietnam                          36
#  Poland                           34
#  Columbia                         32
#  Taiwan                           26
#  Portugal                         24
#  Greece                           24
#  Ecuador                          24
# ...

# %%
train
# Out:
#        age          workclass  fnlwgt      education  education-num  \
# no
# 1       25            Private  219199           11th              7
# 2       39            Private   52978   Some-college             10
# 3       35            Private  196899      Bachelors             13
# 4       64            Private  135527      Assoc-voc             11
# 5       24            Private   60783   Some-college             10
# ...    ...                ...     ...            ...            ...
# 29301   20            Private  100605        HS-grad              9
# 29302   21            Private  372636        HS-grad              9
# 29303   18   Self-emp-not-inc  258474           10th              6
# 29304   33            Private  157446           11th              7
# 29305   65             Others   94809        HS-grad              9
#
#             marital-status          occupation    relationship  \
# no
# 1                 Divorced   Machine-op-inspct   Not-in-family
# ...

# %% [markdown]
# train, test 데이터 모두 교체 완료!

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29305 entries, 1 to 29305
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             29305 non-null  int64
#  1   workclass       29305 non-null  object
#  2   fnlwgt          29305 non-null  int64
#  3   education       29305 non-null  object
#  4   education-num   29305 non-null  int64
#  5   marital-status  29305 non-null  object
#  6   occupation      29305 non-null  object
#  7   relationship    29305 non-null  object
#  8   race            29305 non-null  object
#  9   sex             29305 non-null  object
#  10  capital-gain    29305 non-null  int64
#  11  capital-loss    29305 non-null  int64
#  12  hours-per-week  29305 non-null  int64
#  13  native-country  29305 non-null  object
#  14  income          29305 non-null  int64
# dtypes: int64(7), object(8)
# memory usage: 3.6+ MB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19537 entries, 29306 to 48842
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             19537 non-null  int64
#  1   workclass       19537 non-null  object
#  2   fnlwgt          19537 non-null  int64
#  3   education       19537 non-null  object
#  4   education-num   19537 non-null  int64
#  5   marital-status  19537 non-null  object
#  6   occupation      19537 non-null  object
#  7   relationship    19537 non-null  object
#  8   race            19537 non-null  object
#  9   sex             19537 non-null  object
#  10  capital-gain    19537 non-null  int64
#  11  capital-loss    19537 non-null  int64
#  12  hours-per-week  19537 non-null  int64
#  13  native-country  19537 non-null  object
# dtypes: int64(6), object(8)
# memory usage: 2.2+ MB

# %%
train['workclass'].unique()
# Out:
# array([' Private', ' Self-emp-not-inc', ' Local-gov', 'Others',
#        ' State-gov', ' Self-emp-inc', ' Federal-gov', ' Without-pay',
#        ' Never-worked'], dtype=object)

# %%
test['workclass'].unique()
# Out:
# array(['Others', ' Private', ' Self-emp-not-inc', ' Local-gov',
#        ' Self-emp-inc', ' State-gov', ' Federal-gov', ' Without-pay',
#        ' Never-worked'], dtype=object)

# %% [markdown]
# ### 데이터 시각화

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 단일 컬럼 시각화

# %% [markdown]
# - age 컬럼 시각화

# %%
sns.countplot(data=train,
              x='age',
              hue='income'   
              )
#plt.xlim(0,30)
plt.xlim(30,50)
#plt.xlim(50,90)
# Out:
# (30.0, 50.0)

# %% [markdown]
# 17 \~ 26세는 수입 50k 이하가 압도적이구나!<br>
# 숫자형 age를 범주화하기는 힘들까?
# --> 경제 활동 활발한 나이(청년, 중장년층) / 경제 활동 저조한 나이대(노인)??

# %%
df = train.loc[:, ['age', 'income']]
df[df['age'] > 70]

#is70 = df['age'] > 70
#is50k = df['income'] == 1

#df[is70 & is50k]     #--> 90/533
# Out:
#        age  income
# no
# 181     75       0
# 219     73       0
# 248     72       0
# 284     76       0
# 391     74       0
# ...    ...     ...
# 28993   77       0
# 28996   77       0
# 29049   80       0
# 29065   74       1
# 29092   90       0
#
# [533 rows x 2 columns]

# %%
df = train.loc[:, ['age', 'income']]
#df[df['age'] < 25].head(20)
df[df['age'] < 25].tail(10)
# Out:
#        age  income
# no
# 29277   22       0
# 29279   23       0
# 29281   22       0
# 29282   17       0
# 29287   21       0
# 29299   19       0
# 29300   23       0
# 29301   20       0
# 29302   21       0
# 29303   18       0

# %% [markdown]
# - workclass 시각화

# %%
sns.countplot(data=train,
              y='workclass',
              hue='income'   
              )

# %% [markdown]
# 직업 분류 중에서는 private이 가장 많다!<br>
# without-pay와 Never-worked는 합쳐도 되겠다!

# %% [markdown]
# - fnlwgt 시각화

# %%
# sns.countplot(data=train,
#               x='fnlwgt',
#               hue='income'   
#               )
# plt.xlim(10,40)

# %% [markdown]
# 가중치는 나이(그 외)와 관련 있으나 두드러지는 특징은 없구나! -> 삭제/냅두기

# %% [markdown]
# 상관관계 분석

# %%
import matplotlib.pyplot as plt       
import seaborn as sns

plt.figure(figsize=(8, 6))
sns.heatmap(train.corr(), annot=True) # 상관관계 파악 위해 heatmap으로 수치형 데이터를 간단히 시각화

# %%
sns.countplot(data=train,
              x='education-num',
              hue='income'   
              )

# %% [markdown]
# - age와 sex를 바이올린 형태로 시각화

# %%
plt.figure(figsize=(10,10))
# 바이올린 형태로 시각화
sns.violinplot(data=train,
              x='sex',
              y='age',
              hue='income',
              split=True       
              )
plt.grid()

# %% [markdown]
# 남자는 22\~37세 쯤 수입이 가장 없고 37\~43세 쯤 수입이 가장 많구나!<br>
# 여자는 20\~22세 쯤 수입이 가장 없고 37\~40세 쯤 수입이 가장 많구나!<br>
# 남자와 여자의 나이대별 수입에 차이가 있다!

# %%
# train['fnlwgt'] /= 10000
# train['fnlwgt'] = train['fnlwgt'].astype(int)

# train['fnlwgt']

# %% [markdown]
# ### 데이터 컬럼 병합 및 삭제

# %% [markdown]
# - fnlwgt 삭제하기

# %%
train.drop('fnlwgt', axis = 1, inplace=True)

# %%
test.drop('fnlwgt', axis = 1, inplace=True)

# %%
test
# Out:
#        age          workclass      education  education-num  \
# no
# 29306   18             Others   Some-college             10
# 29307   29            Private        HS-grad              9
# 29308   45            Private      Bachelors             13
# 29309   42   Self-emp-not-inc      Bachelors             13
# 29310   41            Private      Doctorate             16
# ...    ...                ...            ...            ...
# 48838   45   Self-emp-not-inc        HS-grad              9
# 48839   48            Private        HS-grad              9
# 48840   63            Private   Some-college             10
# 48841   18            Private           11th              7
# 48842   31            Private     Assoc-acdm             12
#
#             marital-status        occupation    relationship    race      sex  \
# no
# 29306        Never-married            Others       Own-child   White     Male
# ...

# %% [markdown]
# # 모델 예측

# %% [markdown]
# ### 문제, 정답 데이터로 분리

# %%
y_train = train['income']
X_train = train.drop('income', axis=1)
X_test = test

# %%
X_train.columns
# Out:
# Index(['age', 'workclass', 'education', 'education-num', 'marital-status',
#        'occupation', 'relationship', 'race', 'sex', 'capital-gain',
#        'capital-loss', 'hours-per-week', 'native-country'],
#       dtype='object')

# %%
X_test.columns
# Out:
# Index(['age', 'workclass', 'education', 'education-num', 'marital-status',
#        'occupation', 'relationship', 'race', 'sex', 'capital-gain',
#        'capital-loss', 'hours-per-week', 'native-country'],
#       dtype='object')

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29305 entries, 1 to 29305
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             29305 non-null  int64
#  1   workclass       29305 non-null  object
#  2   education       29305 non-null  object
#  3   education-num   29305 non-null  int64
#  4   marital-status  29305 non-null  object
#  5   occupation      29305 non-null  object
#  6   relationship    29305 non-null  object
#  7   race            29305 non-null  object
#  8   sex             29305 non-null  object
#  9   capital-gain    29305 non-null  int64
#  10  capital-loss    29305 non-null  int64
#  11  hours-per-week  29305 non-null  int64
#  12  native-country  29305 non-null  object
#  13  income          29305 non-null  int64
# dtypes: int64(6), object(8)
# memory usage: 4.6+ MB

# %% [markdown]
# ### 훈련, 테스트 데이터 원핫 인코딩 하기

# %%
X_train = pd.get_dummies(X_train)
X_test = pd.get_dummies(X_test)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (29305, 107)
# (19537, 106)

# %% [markdown]
# ### 컬럼 개수 맞추기

# %%
set(X_train.columns) - set(X_test.columns)
# Out:
# {'native-country_ Holand-Netherlands'}

# %%
# 'native-country_ Holand-Netherlands'의 컬럼은 생기지만 실제로 컴퓨터가 데이터는 없는 것으로 인식함!
X_test['native-country_ Holand-Netherlands'] = 0

# %%
tmp = X_train.columns
for x in tmp :
    print(x)
# Out:
# age
# education-num
# capital-gain
# capital-loss
# hours-per-week
# workclass_ Federal-gov
# workclass_ Local-gov
# workclass_ Never-worked
# workclass_ Private
# workclass_ Self-emp-inc
# workclass_ Self-emp-not-inc
# workclass_ State-gov
# workclass_ Without-pay
# workclass_Others
# education_ 10th
# education_ 11th
# education_ 12th
# education_ 1st-4th
# education_ 5th-6th
# education_ 7th-8th
# education_ 9th
# education_ Assoc-acdm
# education_ Assoc-voc
# education_ Bachelors
# education_ Doctorate
# education_ HS-grad
# education_ Masters
# education_ Preschool
# education_ Prof-school
# education_ Some-college
# marital-status_ Divorced
# marital-status_ Married-AF-spouse
# marital-status_ Married-civ-spouse
# marital-status_ Married-spouse-absent
# marital-status_ Never-married
# marital-status_ Separated
# marital-status_ Widowed
# occupation_ Adm-clerical
# occupation_ Armed-Forces
# occupation_ Craft-repair
# occupation_ Exec-managerial
# occupation_ Farming-fishing
# ...

# %%
tmp = X_test.columns
for x in tmp :
    print(x)
# Out:
# age
# education-num
# capital-gain
# capital-loss
# hours-per-week
# workclass_ Federal-gov
# workclass_ Local-gov
# workclass_ Never-worked
# workclass_ Private
# workclass_ Self-emp-inc
# workclass_ Self-emp-not-inc
# workclass_ State-gov
# workclass_ Without-pay
# workclass_Others
# education_ 10th
# education_ 11th
# education_ 12th
# education_ 1st-4th
# education_ 5th-6th
# education_ 7th-8th
# education_ 9th
# education_ Assoc-acdm
# education_ Assoc-voc
# education_ Bachelors
# education_ Doctorate
# education_ HS-grad
# education_ Masters
# education_ Preschool
# education_ Prof-school
# education_ Some-college
# marital-status_ Divorced
# marital-status_ Married-AF-spouse
# marital-status_ Married-civ-spouse
# marital-status_ Married-spouse-absent
# marital-status_ Never-married
# marital-status_ Separated
# marital-status_ Widowed
# occupation_ Adm-clerical
# occupation_ Armed-Forces
# occupation_ Craft-repair
# occupation_ Exec-managerial
# occupation_ Farming-fishing
# ...

# %%
# 위치 변경을 위해 'native-country_ Holand-Netherlands' 컬럼을 tmp 변수에 넣어줌

tmp = X_train['native-country_ Holand-Netherlands']

# %%
X_train.drop('native-country_ Holand-Netherlands', axis = 1, inplace=True)

# %%
X_train = pd.concat([X_train, tmp],axis=1)
X_train
# Out:
#        age  education-num  capital-gain  capital-loss  hours-per-week  \
# no
# 1       25              7             0             0              40
# 2       39             10             0          1721              55
# 3       35             13             0             0              50
# 4       64             11             0             0              40
# 5       24             10             0             0              70
# ...    ...            ...           ...           ...             ...
# 29301   20              9             0             0              40
# 29302   21              9             0             0              40
# 29303   18              6             0             0              40
# 29304   33              7             0             0              65
# 29305   65              9             0             0              40
#
#        workclass_ Federal-gov  workclass_ Local-gov  workclass_ Never-worked  \
# no
# ...

# %%
X_test
# Out:
#        age  education-num  capital-gain  capital-loss  hours-per-week  \
# no
# 29306   18             10             0             0              16
# 29307   29              9             0             0              40
# 29308   45             13             0             0              40
# 29309   42             13             0             0              40
# 29310   41             16             0          1902              40
# ...    ...            ...           ...           ...             ...
# 48838   45              9             0             0              60
# 48839   48              9             0             0              50
# 48840   63             10          4386             0              40
# 48841   18              7             0             0              20
# 48842   31             12             0             0              46
#
#        workclass_ Federal-gov  workclass_ Local-gov  workclass_ Never-worked  \
# no
# ...

# %% [markdown]
# ### Scaler 생성하기

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
transform_X_train = scaler.transform(X_train)
transform_X_train
# Out:
# array([[-0.9938574 , -1.1994807 , -0.14468936, ..., -0.02106673,
#         -0.13107835, -0.00584166],
#        [ 0.02479914, -0.03231398, -0.14468936, ..., -0.02106673,
#         -0.13107835, -0.00584166],
#        [-0.26624559,  1.13485273, -0.14468936, ..., -0.02106673,
#         -0.13107835, -0.00584166],
#        ...,
#        [-1.50318567, -1.58853627, -0.14468936, ..., -0.02106673,
#         -0.13107835, -0.00584166],
#        [-0.41176795, -1.1994807 , -0.14468936, ..., -0.02106673,
#         -0.13107835, -0.00584166],
#        [ 1.91658984, -0.42136955, -0.14468936, ..., -0.02106673,
#         -0.13107835, -0.00584166]])

# %%
transform_X_test = scaler.transform(X_test)
transform_X_test
# Out:
# array([[-1.50318567, -0.03231398, -0.14468936, ..., -0.02106673,
#         -0.13107835, -0.00584166],
#        [-0.70281267, -0.42136955, -0.14468936, ..., -0.02106673,
#         -0.13107835, -0.00584166],
#        [ 0.46136622,  1.13485273, -0.14468936, ..., -0.02106673,
#         -0.13107835, -0.00584166],
#        ...,
#        [ 1.77106748, -0.03231398,  0.44045488, ..., -0.02106673,
#         -0.13107835, -0.00584166],
#        [-1.50318567, -1.1994807 , -0.14468936, ..., -0.02106673,
#         -0.13107835, -0.00584166],
#        [-0.55729031,  0.74579716, -0.14468936, ..., -0.02106673,
#         -0.13107835, -0.00584166]])

# %% [markdown]
# ### 모델 생성하기

# %%
# !pip install lightgbm

# %%
# !pip install xgboost

# %%
from sklearn.model_selection import cross_val_score, train_test_split, KFold
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
lgb_model = LGBMClassifier(n_estimators = 1000, learning_rate=0.01, random_state=123)
lgb_model.fit(transform_X_train, y_train)
# Out:
# LGBMClassifier(learning_rate=0.01, n_estimators=1000, random_state=123)

# %%
xgb_model = XGBClassifier(n_estimators = 100, learning_rate=0.01, random_state = 123)
xgb_model.fit(transform_X_train, y_train)
# Out:
# C:\Users\163900\Anaconda3\lib\site-packages\xgboost\sklearn.py:892: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [17:31:35] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
# ...

# %%
rf_model = RandomForestClassifier(n_estimators=100, random_state= 11)
rf_model.fit(transform_X_train, y_train)
# Out:
# RandomForestClassifier(random_state=11)

# %% [markdown]
# ### 교차 검증하기

# %% [markdown]
# Standard Scaler를 적용한 예측 모델 kfold 교차 검증

# %% [markdown]
# - LightGBM 모델 정확도와 f1 구하기

# %%
kfold = KFold(n_splits=10, random_state=123, shuffle=True)

# %%
result1 = cross_val_score(lgb_model,
                         transform_X_train,
                         y_train,
                         cv = kfold
                        )

print(result1.mean())
# Out:
# 0.8713875332883859

# %% [markdown]
# 정확도 비교 결과 : fnlwgt 컬럼 그대로 두기!!
# 정확도 비교 결과 &nbsp;<br>
# 1. 원본\: \= 0.872513522042239<br>
# 2. fnlwgt 삭제 \= 0.8713875332883859

# %%
f1_result1 = cross_val_score(lgb_model, # lgb 모델
                         transform_X_train,
                         y_train,
                         cv = kfold,
                         scoring='f1'
                        )

print(f1_result1.mean())
# Out:
# 0.7089981375352713

# %% [markdown]
# - XGBoost 모델 정확도와 f1 구하기

# %%
result2 = cross_val_score(xgb_model,
                         transform_X_train,
                         y_train,
                         cv = kfold
                        )

print(result2.mean())
# Out:
# C:\Users\163900\Anaconda3\lib\site-packages\xgboost\sklearn.py:892: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [17:36:04] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# ...

# %%
f1_result2 = cross_val_score(xgb_model,
                         transform_X_train,
                         y_train,
                         cv = kfold,
                         scoring='f1'   
                        )

print(f1_result2.mean())
# Out:
# [17:38:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:38:26] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:38:38] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# ...

# %% [markdown]
# - RandomForest 모델 정확도와 f1 구하기

# %%
result3 = cross_val_score(rf_model,
                         transform_X_train,
                         y_train,
                         cv = kfold
                        )

print(result3.mean())
# Out:
# 0.8444637935310781

# %%
f1_result3 = cross_val_score(rf_model,
                         transform_X_train,
                         y_train,
                         cv = kfold,
                         scoring='f1'   
                        )

print(f1_result3.mean())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-82-7f44229dca19> in <module>
# ----> 1 f1_result3 = cross_val_score(rf_model,
#       2                          transform_X_train,
#       3                          y_train,
#       4                          cv = kfold,
#       5                          scoring='f1'
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# ~\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     399     scorer = check_scoring(estimator, scoring=scoring)
# ...

# %% [markdown]
# # Kaggle 제출용 파일 만들기

# %%
result = pd.read_csv('sample_submission.csv')
result

# %%
pre = lgb_model.predict(transform_X_test)  # 모델로 예측

# %%
result['income'] = pre

# %%
# result.to_csv('submission.csv', index=False)
